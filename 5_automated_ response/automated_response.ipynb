# %% [markdown]
# # Automated Response
# - **Objective:** To generate alerts when certain fault conditions occur

# %%
# Import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split  # Split data for training and testing
from sklearn.preprocessing import LabelEncoder  # Convert text to numbers
from sklearn.tree import DecisionTreeClassifier  # Machine learning model
from sklearn.metrics import classification_report, confusion_matrix  # Check how well the model works

# %%
# Read data file
df = pd.read_csv('lighting_data_cleaned.csv')

# Display data
df
# Out:
#     light_id   location_name      fault_type            timestamp  \
# 0      L0602       Chinatown   Power-Related  2020-01-06 06:34:34
# 1      L0616          Bishan   Power-Related  2020-01-06 09:20:51
# 2      L0199  Bugis Junction   Power-Related  2020-01-06 19:45:33
# 3      L0036       Chinatown   Power-Related  2020-01-07 10:49:23
# 4      L0259       Pasir Ris   Power-Related  2020-01-08 16:49:23
# ..       ...             ...             ...                  ...
# 189    L0718       Pasir Ris  Control System  2020-12-27 07:38:39
# 190    L0539  Bugis Junction   Communication  2020-12-28 03:03:47
# 191    L0281     Outram Park   Power-Related  2020-12-28 03:22:38
# 192    L0169          Bishan   Environmental  2020-12-28 07:31:05
# 193    L0738       Toa Payoh   Environmental  2020-12-30 01:05:55
#
#     severity_level  fault_status  maintenance_cost  year  month  day  \
# 0    Informational      Resolved            435.43  2020      1    6
# 1    Informational  Acknowledged            456.65  2020      1    6
# 2         Critical        Closed            336.82  2020      1    6
# 3             High      Resolved            368.61  2020      1    7
# 4         Critical        Closed            179.93  2020      1    8
# ..             ...           ...               ...   ...    ...  ...
# 189       Critical      Resolved            482.28  2020     12   27
# 190  Informational      Detected            183.64  2020     12   28
# 191           High        Closed            380.25  2020     12   28
# 192       Critical      Detected            308.93  2020     12   28
# 193           High      Resolved            350.29  2020     12   30
#
#     day_of_week  hour
# 0        Monday     6
# 1        Monday     9
# 2        Monday    19
# 3       Tuesday    10
# 4     Wednesday    16
# ..          ...   ...
# 189      Sunday     7
# 190      Monday     3
# 191      Monday     3
# 192      Monday     7
# 193   Wednesday     1
#
# [194 rows x 12 columns]

# %%
# Filter faults with severity High or Critical
alert_faults = df[df['severity_level'].isin(['High', 'Critical'])]

# Filter df to include only rows where:
power_alerts = df[
    (df['fault_type'] == 'Power-related') &  # Condition 1: fault_type must be 'Power-related'
    (df['severity_level'].isin(['Medium', 'High', 'Critical']))  # Condition 2: severity_level must be one of these values
]

all_alerts = (
    pd.concat([alert_faults, power_alerts])  # Combine the two filtered dfs 'alert_faults' and 'power_alerts' into one df
    .drop_duplicates()                      # Remove duplicates
    .reset_index(drop=True)                 # Reset index starting at 0
)

# Print total number of alert records in the 'all_alerts' df
print(f"Total alerts generated: {len(all_alerts)}")

# Alert display
for idx, row in all_alerts.iterrows():
    print(f"ALERT: Fault '{row['fault_type']}' at '{row['location_name']}' with severity '{row['severity_level']}' on {row['timestamp']}")
# Out:
# Total alerts generated: 83
# ALERT: Fault 'Power-Related' at 'Bugis Junction' with severity 'Critical' on 2020-01-06 19:45:33
# ALERT: Fault 'Power-Related' at 'Chinatown' with severity 'High' on 2020-01-07 10:49:23
# ALERT: Fault 'Power-Related' at 'Pasir Ris' with severity 'Critical' on 2020-01-08 16:49:23
# ALERT: Fault 'Environmental' at 'Toa Payoh' with severity 'Critical' on 2020-01-09 14:06:04
# ALERT: Fault 'Power-Related' at 'Chinatown' with severity 'High' on 2020-01-10 14:52:47
# ALERT: Fault 'Communication' at 'Jurong West' with severity 'High' on 2020-01-11 07:04:34
# ALERT: Fault 'Environmental' at 'Bishan' with severity 'Critical' on 2020-01-13 16:26:42
# ALERT: Fault 'Cybersecurity' at 'Pasir Ris' with severity 'High' on 2020-01-18 01:03:03
# ALERT: Fault 'Communication' at 'Jurong West' with severity 'Critical' on 2020-01-20 04:43:34
# ALERT: Fault 'Power-Related' at 'Chinatown' with severity 'Critical' on 2020-01-23 05:21:50
# ALERT: Fault 'Communication' at 'Bugis Junction' with severity 'High' on 2020-01-26 18:52:07
# ALERT: Fault 'Environmental' at 'Bishan' with severity 'Critical' on 2020-02-10 05:50:51
# ALERT: Fault 'Communication' at 'Chinatown' with severity 'High' on 2020-02-11 10:37:24
# ALERT: Fault 'Control System' at 'City Hall' with severity 'High' on 2020-02-16 08:27:27
# ALERT: Fault 'Communication' at 'Bishan' with severity 'Critical' on 2020-02-17 16:11:38
# ALERT: Fault 'Power-Related' at 'Pasir Ris' with severity 'Critical' on 2020-02-20 16:10:27
# ALERT: Fault 'Cybersecurity' at 'Canberra' with severity 'Critical' on 2020-03-01 02:16:37
# ALERT: Fault 'Control System' at 'City Hall' with severity 'Critical' on 2020-03-09 21:26:48
# ALERT: Fault 'Communication' at 'Bishan' with severity 'High' on 2020-03-16 13:54:07
# ALERT: Fault 'Power-Related' at 'Pasir Ris' with severity 'High' on 2020-03-21 03:06:08
# ALERT: Fault 'Environmental' at 'Canberra' with severity 'High' on 2020-03-22 19:28:45
# ALERT: Fault 'Environmental' at 'Canberra' with severity 'High' on 2020-03-23 06:19:08
# ALERT: Fault 'Communication' at 'Bugis Junction' with severity 'High' on 2020-03-29 18:05:24
# ALERT: Fault 'Control System' at 'Pasir Ris' with severity 'High' on 2020-03-29 21:40:49
# ALERT: Fault 'Power-Related' at 'Pasir Ris' with severity 'High' on 2020-04-16 00:39:18
# ALERT: Fault 'Sensor-Related' at 'Orchard Road' with severity 'Critical' on 2020-04-16 20:28:03
# ALERT: Fault 'Communication' at 'Pasir Ris' with severity 'Critical' on 2020-04-27 08:03:12
# ALERT: Fault 'Cybersecurity' at 'Outram Park' with severity 'Critical' on 2020-05-13 17:30:04
# ALERT: Fault 'Power-Related' at 'Orchard Road' with severity 'Critical' on 2020-05-16 19:45:33
# ALERT: Fault 'Power-Related' at 'Canberra' with severity 'High' on 2020-05-26 07:12:19
# ALERT: Fault 'Control System' at 'Chinatown' with severity 'Critical' on 2020-06-01 05:26:02
# ALERT: Fault 'Control System' at 'Orchard Road' with severity 'Critical' on 2020-06-02 06:19:50
# ALERT: Fault 'Communication' at 'Orchard Road' with severity 'Critical' on 2020-06-02 20:10:14
# ALERT: Fault 'Sensor-Related' at 'City Hall' with severity 'Critical' on 2020-06-03 07:01:57
# ALERT: Fault 'Environmental' at 'City Hall' with severity 'High' on 2020-06-09 21:07:57
# ALERT: Fault 'Communication' at 'Chinatown' with severity 'Critical' on 2020-06-29 00:02:49
# ALERT: Fault 'Communication' at 'Chinatown' with severity 'High' on 2020-07-01 12:15:23
# ALERT: Fault 'Communication' at 'Pasir Ris' with severity 'Critical' on 2020-07-02 09:11:17
# ALERT: Fault 'Environmental' at 'Toa Payoh' with severity 'Critical' on 2020-07-05 00:38:36
# ALERT: Fault 'Environmental' at 'Canberra' with severity 'Critical' on 2020-07-05 07:42:37
# ALERT: Fault 'Sensor-Related' at 'Orchard Road' with severity 'High' on 2020-07-08 00:48:13
# ALERT: Fault 'Control System' at 'Bugis Junction' with severity 'Critical' on 2020-07-08 12:45:04
# ALERT: Fault 'Communication' at 'Canberra' with severity 'Critical' on 2020-07-10 07:24:54
# ALERT: Fault 'Cybersecurity' at 'City Hall' with severity 'High' on 2020-07-11 09:36:59
# ALERT: Fault 'Power-Related' at 'Toa Payoh' with severity 'High' on 2020-07-14 14:21:14
# ALERT: Fault 'Sensor-Related' at 'Pasir Ris' with severity 'High' on 2020-07-20 10:16:57
# ALERT: Fault 'Environmental' at 'City Hall' with severity 'Critical' on 2020-07-23 08:13:39
# ALERT: Fault 'Cybersecurity' at 'Toa Payoh' with severity 'Critical' on 2020-07-26 09:31:17
# ALERT: Fault 'Sensor-Related' at 'Pasir Ris' with severity 'High' on 2020-07-29 01:10:09
# ALERT: Fault 'Sensor-Related' at 'Outram Park' with severity 'Critical' on 2020-07-31 02:47:55
# ALERT: Fault 'Power-Related' at 'Chinatown' with severity 'High' on 2020-08-07 02:21:22
# ALERT: Fault 'Sensor-Related' at 'City Hall' with severity 'Critical' on 2020-08-12 00:14:38
# ALERT: Fault 'Sensor-Related' at 'Jurong West' with severity 'High' on 2020-08-12 06:29:35
# ALERT: Fault 'Sensor-Related' at 'Toa Payoh' with severity 'High' on 2020-08-22 11:04:59
# ALERT: Fault 'Control System' at 'Orchard Road' with severity 'Critical' on 2020-08-22 13:49:55
# ALERT: Fault 'Environmental' at 'Bishan' with severity 'Critical' on 2020-08-24 02:34:51
# ALERT: Fault 'Control System' at 'Pasir Ris' with severity 'High' on 2020-08-25 02:01:32
# ALERT: Fault 'Power-Related' at 'City Hall' with severity 'Critical' on 2020-08-26 02:09:03
# ALERT: Fault 'Communication' at 'Toa Payoh' with severity 'Critical' on 2020-08-28 09:21:12
# ALERT: Fault 'Cybersecurity' at 'Canberra' with severity 'High' on 2020-08-31 08:32:36
# ALERT: Fault 'Power-Related' at 'Pasir Ris' with severity 'Critical' on 2020-09-02 11:54:07
# ALERT: Fault 'Sensor-Related' at 'Bishan' with severity 'Critical' on 2020-09-04 15:44:58
# ALERT: Fault 'Power-Related' at 'Toa Payoh' with severity 'Critical' on 2020-09-09 07:33:01
# ALERT: Fault 'Control System' at 'Canberra' with severity 'High' on 2020-09-22 08:35:26
# ALERT: Fault 'Environmental' at 'Outram Park' with severity 'High' on 2020-09-22 22:06:49
# ALERT: Fault 'Cybersecurity' at 'Outram Park' with severity 'High' on 2020-10-02 10:34:37
# ALERT: Fault 'Environmental' at 'Chinatown' with severity 'High' on 2020-10-03 09:12:02
# ALERT: Fault 'Cybersecurity' at 'Orchard Road' with severity 'High' on 2020-10-08 06:30:54
# ALERT: Fault 'Control System' at 'Orchard Road' with severity 'High' on 2020-10-12 16:25:21
# ALERT: Fault 'Cybersecurity' at 'Bishan' with severity 'High' on 2020-10-28 06:23:56
# ALERT: Fault 'Sensor-Related' at 'Canberra' with severity 'Critical' on 2020-11-02 23:37:55
# ALERT: Fault 'Cybersecurity' at 'City Hall' with severity 'Critical' on 2020-11-18 18:00:47
# ALERT: Fault 'Power-Related' at 'Chinatown' with severity 'High' on 2020-11-26 11:58:09
# ALERT: Fault 'Communication' at 'Chinatown' with severity 'Critical' on 2020-11-26 15:53:00
# ALERT: Fault 'Power-Related' at 'Chinatown' with severity 'High' on 2020-12-01 21:42:48
# ALERT: Fault 'Sensor-Related' at 'Toa Payoh' with severity 'High' on 2020-12-04 00:13:02
# ALERT: Fault 'Cybersecurity' at 'Bishan' with severity 'Critical' on 2020-12-05 09:22:52
# ALERT: Fault 'Communication' at 'City Hall' with severity 'Critical' on 2020-12-14 13:20:05
# ALERT: Fault 'Sensor-Related' at 'Toa Payoh' with severity 'Critical' on 2020-12-21 14:30:34
# ALERT: Fault 'Control System' at 'Pasir Ris' with severity 'Critical' on 2020-12-27 07:38:39
# ALERT: Fault 'Power-Related' at 'Outram Park' with severity 'High' on 2020-12-28 03:22:38
# ALERT: Fault 'Environmental' at 'Bishan' with severity 'Critical' on 2020-12-28 07:31:05
# ALERT: Fault 'Environmental' at 'Toa Payoh' with severity 'High' on 2020-12-30 01:05:55

# %%
# Create a new dataframe with only selected columns from all_alerts
styled_alerts = all_alerts[['fault_type', 'location_name', 'severity_level', 'timestamp']].copy()

# Define severity levels colours
severity_colors = {
    "Critical": "background-color: #ff4d4d; color: white; font-weight: bold;", # Red
    "High": "background-color: #ffa500; color: white; font-weight: bold;", # Orange
    "Medium": "background-color: #ffeb3b; color: black;" # Yellow
}

# Return colour for the given severity level
def highlight_severity(val):
    return severity_colors.get(val, "")

# Apply color styling to the severity_level column and set table styles
styled_alerts.style.applymap(highlight_severity, subset=['severity_level']) \
    .set_table_styles([
        {'selector': 'thead th', 'props': [('background-color', '#333'), ('color', 'white'), ('font-weight', 'bold')]},
        {'selector': 'tbody td', 'props': [('border', '1px solid #ccc'), ('padding', '6px')]},
    ]) \
    .set_properties(**{'text-align': 'center'})
# Out:
# /tmp/ipykernel_350/3651884140.py:16: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_alerts.style.applymap(highlight_severity, subset=['severity_level']) \
# <style type="text/css">
# #T_293ce thead th {
#   background-color: #333;
#   color: white;
#   font-weight: bold;
# }
# #T_293ce tbody td {
#   border: 1px solid #ccc;
#   padding: 6px;
# }
# #T_293ce_row0_col0, #T_293ce_row0_col1, #T_293ce_row0_col3, #T_293ce_row1_col0, #T_293ce_row1_col1, #T_293ce_row1_col3, #T_293ce_row2_col0, #T_293ce_row2_col1, #T_293ce_row2_col3, #T_293ce_row3_col0, #T_293ce_row3_col1, #T_293ce_row3_col3, #T_293ce_row4_col0, #T_293ce_row4_col1, #T_293ce_row4_col3, #T_293ce_row5_col0, #T_293ce_row5_col1, #T_293ce_row5_col3, #T_293ce_row6_col0, #T_293ce_row6_col1, #T_293ce_row6_col3, #T_293ce_row7_col0, #T_293ce_row7_col1, #T_293ce_row7_col3, #T_293ce_row8_col0, #T_293ce_row8_col1, #T_293ce_row8_col3, #T_293ce_row9_col0, #T_293ce_row9_col1, #T_293ce_row9_col3, #T_293ce_row10_col0, #T_293ce_row10_col1, #T_293ce_row10_col3, #T_293ce_row11_col0, #T_293ce_row11_col1, #T_293ce_row11_col3, #T_293ce_row12_col0, #T_293ce_row12_col1, #T_293ce_row12_col3, #T_293ce_row13_col0, #T_293ce_row13_col1, #T_293ce_row13_col3, #T_293ce_row14_col0, #T_293ce_row14_col1, #T_293ce_row14_col3, #T_293ce_row15_col0, #T_293ce_row15_col1, #T_293ce_row15_col3, #T_293ce_row16_col0, #T_293ce_row16_col1, #T_293ce_row16_col3, #T_293ce_row17_col0, #T_293ce_row17_col1, #T_293ce_row17_col3, #T_293ce_row18_col0, #T_293ce_row18_col1, #T_293ce_row18_col3, #T_293ce_row19_col0, #T_293ce_row19_col1, #T_293ce_row19_col3, #T_293ce_row20_col0, #T_293ce_row20_col1, #T_293ce_row20_col3, #T_293ce_row21_col0, #T_293ce_row21_col1, #T_293ce_row21_col3, #T_293ce_row22_col0, #T_293ce_row22_col1, #T_293ce_row22_col3, #T_293ce_row23_col0, #T_293ce_row23_col1, #T_293ce_row23_col3, #T_293ce_row24_col0, #T_293ce_row24_col1, #T_293ce_row24_col3, #T_293ce_row25_col0, #T_293ce_row25_col1, #T_293ce_row25_col3, #T_293ce_row26_col0, #T_293ce_row26_col1, #T_293ce_row26_col3, #T_293ce_row27_col0, #T_293ce_row27_col1, #T_293ce_row27_col3, #T_293ce_row28_col0, #T_293ce_row28_col1, #T_293ce_row28_col3, #T_293ce_row29_col0, #T_293ce_row29_col1, #T_293ce_row29_col3, #T_293ce_row30_col0, #T_293ce_row30_col1, #T_293ce_row30_col3, #T_293ce_row31_col0, #T_293ce_row31_col1, #T_293ce_row31_col3, #T_293ce_row32_col0, #T_293ce_row32_col1, #T_293ce_row32_col3, #T_293ce_row33_col0, #T_293ce_row33_col1, #T_293ce_row33_col3, #T_293ce_row34_col0, #T_293ce_row34_col1, #T_293ce_row34_col3, #T_293ce_row35_col0, #T_293ce_row35_col1, #T_293ce_row35_col3, #T_293ce_row36_col0, #T_293ce_row36_col1, #T_293ce_row36_col3, #T_293ce_row37_col0, #T_293ce_row37_col1, #T_293ce_row37_col3, #T_293ce_row38_col0, #T_293ce_row38_col1, #T_293ce_row38_col3, #T_293ce_row39_col0, #T_293ce_row39_col1, #T_293ce_row39_col3, #T_293ce_row40_col0, #T_293ce_row40_col1, #T_293ce_row40_col3, #T_293ce_row41_col0, #T_293ce_row41_col1, #T_293ce_row41_col3, #T_293ce_row42_col0, #T_293ce_row42_col1, #T_293ce_row42_col3, #T_293ce_row43_col0, #T_293ce_row43_col1, #T_293ce_row43_col3, #T_293ce_row44_col0, #T_293ce_row44_col1, #T_293ce_row44_col3, #T_293ce_row45_col0, #T_293ce_row45_col1, #T_293ce_row45_col3, #T_293ce_row46_col0, #T_293ce_row46_col1, #T_293ce_row46_col3, #T_293ce_row47_col0, #T_293ce_row47_col1, #T_293ce_row47_col3, #T_293ce_row48_col0, #T_293ce_row48_col1, #T_293ce_row48_col3, #T_293ce_row49_col0, #T_293ce_row49_col1, #T_293ce_row49_col3, #T_293ce_row50_col0, #T_293ce_row50_col1, #T_293ce_row50_col3, #T_293ce_row51_col0, #T_293ce_row51_col1, #T_293ce_row51_col3, #T_293ce_row52_col0, #T_293ce_row52_col1, #T_293ce_row52_col3, #T_293ce_row53_col0, #T_293ce_row53_col1, #T_293ce_row53_col3, #T_293ce_row54_col0, #T_293ce_row54_col1, #T_293ce_row54_col3, #T_293ce_row55_col0, #T_293ce_row55_col1, #T_293ce_row55_col3, #T_293ce_row56_col0, #T_293ce_row56_col1, #T_293ce_row56_col3, #T_293ce_row57_col0, #T_293ce_row57_col1, #T_293ce_row57_col3, #T_293ce_row58_col0, #T_293ce_row58_col1, #T_293ce_row58_col3, #T_293ce_row59_col0, #T_293ce_row59_col1, #T_293ce_row59_col3, #T_293ce_row60_col0, #T_293ce_row60_col1, #T_293ce_row60_col3, #T_293ce_row61_col0, #T_293ce_row61_col1, #T_293ce_row61_col3, #T_293ce_row62_col0, #T_293ce_row62_col1, #T_293ce_row62_col3, #T_293ce_row63_col0, #T_293ce_row63_col1, #T_293ce_row63_col3 ...
#   text-align: center;
# }
# #T_293ce_row0_col2, #T_293ce_row2_col2, #T_293ce_row3_col2, #T_293ce_row6_col2, #T_293ce_row8_col2, #T_293ce_row9_col2, #T_293ce_row11_col2, #T_293ce_row14_col2, #T_293ce_row15_col2, #T_293ce_row16_col2, #T_293ce_row17_col2, #T_293ce_row25_col2, #T_293ce_row26_col2, #T_293ce_row27_col2, #T_293ce_row28_col2, #T_293ce_row30_col2, #T_293ce_row31_col2, #T_293ce_row32_col2, #T_293ce_row33_col2, #T_293ce_row35_col2, #T_293ce_row37_col2, #T_293ce_row38_col2, #T_293ce_row39_col2, #T_293ce_row41_col2, #T_293ce_row42_col2, #T_293ce_row46_col2, #T_293ce_row47_col2, #T_293ce_row49_col2, #T_293ce_row51_col2, #T_293ce_row54_col2, #T_293ce_row55_col2, #T_293ce_row57_col2, #T_293ce_row58_col2, #T_293ce_row60_col2, #T_293ce_row61_col2, #T_293ce_row62_col2, #T_293ce_row70_col2, #T_293ce_row71_col2, #T_293ce_row73_col2, #T_293ce_row76_col2, #T_293ce_row77_col2, #T_293ce_row78_col2, #T_293ce_row79_col2, #T_293ce_row81_col2 {
#   background-color: #ff4d4d;
#   color: white;
#   font-weight: bold;
#   text-align: center;
# }
# #T_293ce_row1_col2, #T_293ce_row4_col2, #T_293ce_row5_col2, #T_293ce_row7_col2, #T_293ce_row10_col2, #T_293ce_row12_col2, #T_293ce_row13_col2, #T_293ce_row18_col2, #T_293ce_row19_col2, #T_293ce_row20_col2, #T_293ce_row21_col2, #T_293ce_row22_col2, #T_293ce_row23_col2, #T_293ce_row24_col2, #T_293ce_row29_col2, #T_293ce_row34_col2, #T_293ce_row36_col2, #T_293ce_row40_col2, #T_293ce_row43_col2, #T_293ce_row44_col2, #T_293ce_row45_col2, #T_293ce_row48_col2, #T_293ce_row50_col2, #T_293ce_row52_col2, #T_293ce_row53_col2, #T_293ce_row56_col2, #T_293ce_row59_col2, #T_293ce_row63_col2, #T_293ce_row64_col2, #T_293ce_row65_col2, #T_293ce_row66_col2, #T_293ce_row67_col2, #T_293ce_row68_col2, #T_293ce_row69_col2, #T_293ce_row72_col2, #T_293ce_row74_col2, #T_293ce_row75_col2, #T_293ce_row80_col2, #T_293ce_row82_col2 {
#   background-color: #ffa500;
#   color: white;
#   font-weight: bold;
#   text-align: center;
# }
# </style>
# <table id="T_293ce" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_293ce_level0_col0" class="col_heading level0 col0" >fault_type</th>
#       <th id="T_293ce_level0_col1" class="col_heading level0 col1" >location_name</th>
#       <th id="T_293ce_level0_col2" class="col_heading level0 col2" >severity_level</th>
#       <th id="T_293ce_level0_col3" class="col_heading level0 col3" >timestamp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_293ce_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_293ce_row0_col0" class="data row0 col0" >Power-Related</td>
#       <td id="T_293ce_row0_col1" class="data
