# %% [markdown]
# # Automated Response
# - **Objective:** To generate alerts when certain fault conditions occur

# %%
# Import libraries
import pandas as pd  # Data tables
import seaborn as sns  # Create charts
import matplotlib.pyplot as plt  # Display charts
from sklearn.model_selection import train_test_split  # Split data for training and testing
from sklearn.preprocessing import LabelEncoder  # Convert text to numbers
from sklearn.tree import DecisionTreeClassifier  # Machine learning model
from sklearn.metrics import classification_report, confusion_matrix  # Check how well the model works

# %%
# Read data file
df = pd.read_csv('lighting_data_cleaned.csv')

# Display data
df
# Out:
#     light_id   location_name      fault_type            timestamp  \
# 0      L0226       Pasir Ris  Control System  2020-01-01 01:22:25
# 1      L0061       City Hall  Control System  2020-01-01 23:45:18
# 2      L0455       Pasir Ris   Power-Related  2020-01-02 01:33:02
# 3      L0924       City Hall   Cybersecurity  2020-01-02 03:34:48
# 4      L0134        Canberra   Communication  2020-01-02 08:09:16
# ..       ...             ...             ...                  ...
# 461    L0835    Orchard Road  Sensor-Related  2020-12-24 23:46:51
# 462    L0452     Jurong West   Environmental  2020-12-25 02:25:42
# 463    L0483          Bishan  Sensor-Related  2020-12-25 02:34:36
# 464    L0683        Canberra  Control System  2020-12-29 20:00:19
# 465    L0934  Bugis Junction   Cybersecurity  2020-12-29 20:44:12
#
#     severity_level  fault_status  maintenance_cost  year  month  day  \
# 0             High  Acknowledged            343.60  2020      1    1
# 1              Low   In Progress            271.80  2020      1    1
# 2    Informational      Resolved            169.20  2020      1    2
# 3    Informational      Resolved            372.45  2020      1    2
# 4              Low   In Progress            335.57  2020      1    2
# ..             ...           ...               ...   ...    ...  ...
# 461         Medium  Acknowledged            482.02  2020     12   24
# 462  Informational      Detected            277.74  2020     12   25
# 463       Critical   In Progress            198.08  2020     12   25
# 464       Critical   In Progress            236.10  2020     12   29
# 465  Informational      Detected            399.61  2020     12   29
#
#     day_of_week  hour
# 0     Wednesday     1
# 1     Wednesday    23
# 2      Thursday     1
# 3      Thursday     3
# 4      Thursday     8
# ..          ...   ...
# 461    Thursday    23
# 462      Friday     2
# 463      Friday     2
# 464     Tuesday    20
# 465     Tuesday    20
#
# [466 rows x 12 columns]

# %%
# Filter faults with severity High or Critical
alert_faults = df[df['severity_level'].isin(['High', 'Critical'])]

# Filter the DataFrame 'df' to include only rows where:
# 1) The 'fault_type' column is exactly 'Power-related'
# AND
# 2) The 'severity_level' column value is either 'Medium', 'High', or 'Critical'
power_alerts = df[
    (df['fault_type'] == 'Power-related') &  # Condition 1: fault_type must be 'Power-related'
    (df['severity_level'].isin(['Medium', 'High', 'Critical']))  # Condition 2: severity_level must be one of these values
]

# Combine the two filtered DataFrames 'alert_faults' and 'power_alerts' into one DataFrame,
# then remove any duplicate rows that might appear in both,
# and finally reset the index of the resulting DataFrame for clean numbering.
all_alerts = (
    pd.concat([alert_faults, power_alerts])  # Concatenate the two DataFrames vertically (stack rows)
    .drop_duplicates()                      # Remove any duplicate rows that exist in both DataFrames
    .reset_index(drop=True)                 # Reset the index to have a clean sequential index starting at 0
)

# Print the total number of alert records in the 'all_alerts' DataFrame
print(f"Total alerts generated: {len(all_alerts)}")

# Example alert display
for idx, row in all_alerts.iterrows():
    print(f"ALERT: Fault '{row['fault_type']}' at '{row['location_name']}' with severity '{row['severity_level']}' on {row['timestamp']}")
# Out:
# Total alerts generated: 199
# ALERT: Fault 'Control System' at 'Pasir Ris' with severity 'High' on 2020-01-01 01:22:25
# ALERT: Fault 'Cybersecurity' at 'Bugis Junction' with severity 'High' on 2020-01-03 19:12:37
# ALERT: Fault 'Control System' at 'Pasir Ris' with severity 'Critical' on 2020-01-04 12:10:28
# ALERT: Fault 'Environmental' at 'Bishan' with severity 'Critical' on 2020-01-05 21:22:55
# ALERT: Fault 'Environmental' at 'Bishan' with severity 'Critical' on 2020-01-08 10:07:10
# ALERT: Fault 'Cybersecurity' at 'Bugis Junction' with severity 'Critical' on 2020-01-11 05:37:07
# ALERT: Fault 'Control System' at 'Bugis Junction' with severity 'Critical' on 2020-01-11 07:03:02
# ALERT: Fault 'Power-Related' at 'Chinatown' with severity 'Critical' on 2020-01-14 01:35:02
# ALERT: Fault 'Environmental' at 'Bishan' with severity 'High' on 2020-01-17 23:13:13
# ALERT: Fault 'Control System' at 'Canberra' with severity 'High' on 2020-01-18 18:28:01
# ALERT: Fault 'Environmental' at 'Toa Payoh' with severity 'Critical' on 2020-01-19 08:14:50
# ALERT: Fault 'Cybersecurity' at 'Orchard Road' with severity 'Critical' on 2020-01-20 06:14:21
# ALERT: Fault 'Sensor-Related' at 'Canberra' with severity 'Critical' on 2020-01-25 13:27:16
# ALERT: Fault 'Control System' at 'Bugis Junction' with severity 'High' on 2020-01-25 15:16:38
# ALERT: Fault 'Communication' at 'City Hall' with severity 'Critical' on 2020-01-26 10:21:35
# ALERT: Fault 'Control System' at 'Pasir Ris' with severity 'High' on 2020-01-28 23:52:34
# ALERT: Fault 'Power-Related' at 'Chinatown' with severity 'Critical' on 2020-01-29 22:39:56
# ALERT: Fault 'Control System' at 'Toa Payoh' with severity 'High' on 2020-02-02 04:05:07
# ALERT: Fault 'Environmental' at 'Bishan' with severity 'Critical' on 2020-02-02 14:49:35
# ALERT: Fault 'Environmental' at 'City Hall' with severity 'High' on 2020-02-03 02:47:47
# ALERT: Fault 'Power-Related' at 'Bugis Junction' with severity 'High' on 2020-02-05 01:53:44
# ALERT: Fault 'Communication' at 'Chinatown' with severity 'High' on 2020-02-14 02:49:52
# ALERT: Fault 'Power-Related' at 'Jurong West' with severity 'High' on 2020-02-14 05:43:40
# ALERT: Fault 'Cybersecurity' at 'Pasir Ris' with severity 'Critical' on 2020-02-21 15:51:24
# ALERT: Fault 'Sensor-Related' at 'Canberra' with severity 'High' on 2020-02-25 01:36:31
# ALERT: Fault 'Communication' at 'Canberra' with severity 'High' on 2020-03-01 20:40:30
# ALERT: Fault 'Cybersecurity' at 'Bugis Junction' with severity 'High' on 2020-03-02 11:40:20
# ALERT: Fault 'Sensor-Related' at 'Pasir Ris' with severity 'High' on 2020-03-06 13:29:30
# ALERT: Fault 'Control System' at 'City Hall' with severity 'High' on 2020-03-07 23:16:45
# ALERT: Fault 'Communication' at 'Pasir Ris' with severity 'High' on 2020-03-08 17:22:39
# ALERT: Fault 'Control System' at 'City Hall' with severity 'High' on 2020-03-09 18:39:48
# ALERT: Fault 'Communication' at 'Toa Payoh' with severity 'Critical' on 2020-03-12 20:55:20
# ALERT: Fault 'Sensor-Related' at 'Bishan' with severity 'High' on 2020-03-13 10:51:55
# ALERT: Fault 'Power-Related' at 'Chinatown' with severity 'High' on 2020-03-15 09:47:15
# ALERT: Fault 'Communication' at 'Canberra' with severity 'High' on 2020-03-16 22:25:05
# ALERT: Fault 'Power-Related' at 'Jurong West' with severity 'High' on 2020-03-16 23:26:19
# ALERT: Fault 'Sensor-Related' at 'Bugis Junction' with severity 'Critical' on 2020-03-20 06:36:49
# ALERT: Fault 'Power-Related' at 'Chinatown' with severity 'Critical' on 2020-03-21 15:16:13
# ALERT: Fault 'Power-Related' at 'Jurong West' with severity 'Critical' on 2020-03-22 06:00:27
# ALERT: Fault 'Power-Related' at 'Bishan' with severity 'High' on 2020-03-27 23:14:17
# ALERT: Fault 'Sensor-Related' at 'Pasir Ris' with severity 'Critical' on 2020-03-28 07:39:00
# ALERT: Fault 'Power-Related' at 'Canberra' with severity 'Critical' on 2020-03-29 16:09:42
# ALERT: Fault 'Communication' at 'Outram Park' with severity 'Critical' on 2020-03-29 22:03:46
# ALERT: Fault 'Communication' at 'Toa Payoh' with severity 'High' on 2020-03-30 23:41:33
# ALERT: Fault 'Power-Related' at 'Pasir Ris' with severity 'High' on 2020-04-01 07:01:04
# ALERT: Fault 'Cybersecurity' at 'Canberra' with severity 'High' on 2020-04-01 14:29:55
# ALERT: Fault 'Control System' at 'Bugis Junction' with severity 'High' on 2020-04-02 03:40:08
# ALERT: Fault 'Control System' at 'Jurong West' with severity 'High' on 2020-04-03 03:33:39
# ALERT: Fault 'Sensor-Related' at 'Canberra' with severity 'Critical' on 2020-04-04 15:35:00
# ALERT: Fault 'Sensor-Related' at 'Pasir Ris' with severity 'Critical' on 2020-04-06 22:33:24
# ALERT: Fault 'Power-Related' at 'Toa Payoh' with severity 'High' on 2020-04-07 08:48:17
# ALERT: Fault 'Sensor-Related' at 'Bugis Junction' with severity 'Critical' on 2020-04-09 01:37:21
# ALERT: Fault 'Power-Related' at 'Bishan' with severity 'High' on 2020-04-10 01:18:34
# ALERT: Fault 'Control System' at 'Bishan' with severity 'High' on 2020-04-11 02:01:39
# ALERT: Fault 'Control System' at 'Bishan' with severity 'Critical' on 2020-04-14 18:37:30
# ALERT: Fault 'Communication' at 'Bishan' with severity 'Critical' on 2020-04-16 18:36:13
# ALERT: Fault 'Power-Related' at 'Canberra' with severity 'Critical' on 2020-04-18 22:36:20
# ALERT: Fault 'Control System' at 'Bugis Junction' with severity 'High' on 2020-04-20 18:20:04
# ALERT: Fault 'Communication' at 'Canberra' with severity 'High' on 2020-04-21 11:51:39
# ALERT: Fault 'Power-Related' at 'Outram Park' with severity 'Critical' on 2020-04-22 00:41:40
# ALERT: Fault 'Sensor-Related' at 'Chinatown' with severity 'High' on 2020-04-22 06:39:39
# ALERT: Fault 'Communication' at 'Toa Payoh' with severity 'High' on 2020-04-22 18:02:25
# ALERT: Fault 'Environmental' at 'Bugis Junction' with severity 'Critical' on 2020-04-22 22:07:59
# ALERT: Fault 'Environmental' at 'Canberra' with severity 'High' on 2020-04-24 23:06:39
# ALERT: Fault 'Control System' at 'Bishan' with severity 'High' on 2020-04-25 03:50:38
# ALERT: Fault 'Sensor-Related' at 'Canberra' with severity 'Critical' on 2020-04-26 23:15:31
# ALERT: Fault 'Sensor-Related' at 'Bugis Junction' with severity 'Critical' on 2020-04-29 13:58:48
# ALERT: Fault 'Environmental' at 'Bugis Junction' with severity 'Critical' on 2020-05-01 17:47:41
# ALERT: Fault 'Cybersecurity' at 'Pasir Ris' with severity 'Critical' on 2020-05-06 00:04:34
# ALERT: Fault 'Cybersecurity' at 'Bugis Junction' with severity 'High' on 2020-05-06 19:18:45
# ALERT: Fault 'Control System' at 'Toa Payoh' with severity 'High' on 2020-05-09 18:49:13
# ALERT: Fault 'Environmental' at 'Bugis Junction' with severity 'Critical' on 2020-05-10 10:41:48
# ALERT: Fault 'Communication' at 'Bishan' with severity 'Critical' on 2020-05-11 20:42:51
# ALERT: Fault 'Cybersecurity' at 'Outram Park' with severity 'High' on 2020-05-12 06:40:17
# ALERT: Fault 'Power-Related' at 'Toa Payoh' with severity 'High' on 2020-05-12 19:52:18
# ALERT: Fault 'Environmental' at 'Orchard Road' with severity 'Critical' on 2020-05-14 12:10:22
# ALERT: Fault 'Communication' at 'City Hall' with severity 'High' on 2020-05-14 12:50:51
# ALERT: Fault 'Communication' at 'City Hall' with severity 'High' on 2020-05-17 09:11:43
# ALERT: Fault 'Cybersecurity' at 'Pasir Ris' with severity 'Critical' on 2020-05-23 22:18:50
# ALERT: Fault 'Control System' at 'Canberra' with severity 'Critical' on 2020-05-24 05:22:21
# ALERT: Fault 'Power-Related' at 'Canberra' with severity 'High' on 2020-05-25 02:04:55
# ALERT: Fault 'Communication' at 'Jurong West' with severity 'Critical' on 2020-05-25 08:55:56
# ALERT: Fault 'Sensor-Related' at 'Bishan' with severity 'High' on 2020-05-26 17:22:37
# ALERT: Fault 'Cybersecurity' at 'Canberra' with severity 'Critical' on 2020-05-27 02:59:21
# ALERT: Fault 'Communication' at 'City Hall' with severity 'Critical' on 2020-05-27 12:49:58
# ALERT: Fault 'Power-Related' at 'Toa Payoh' with severity 'High' on 2020-06-05 00:59:22
# ALERT: Fault 'Environmental' at 'Canberra' with severity 'High' on 2020-06-05 21:30:43
# ALERT: Fault 'Control System' at 'Bishan' with severity 'Critical' on 2020-06-07 00:25:28
# ALERT: Fault 'Environmental' at 'Jurong West' with severity 'High' on 2020-06-09 04:03:29
# ALERT: Fault 'Cybersecurity' at 'City Hall' with severity 'High' on 2020-06-09 14:44:07
# ALERT: Fault 'Power-Related' at 'Toa Payoh' with severity 'Critical' on 2020-06-09 16:49:34
# ALERT: Fault 'Control System' at 'Canberra' with severity 'Critical' on 2020-06-09 20:42:28
# ALERT: Fault 'Environmental' at 'Bugis Junction' with severity 'High' on 2020-06-12 19:58:38
# ALERT: Fault 'Cybersecurity' at 'Pasir Ris' with severity 'Critical' on 2020-06-14 09:16:14
# ALERT: Fault 'Control System' at 'City Hall' with severity 'High' on 2020-06-14 12:09:10
# ALERT: Fault 'Environmental' at 'Canberra' with severity 'Critical' on 2020-06-15 18:10:08
# ALERT: Fault 'Power-Related' at 'City Hall' with severity 'Critical' on 2020-06-16 15:32:29
# ALERT: Fault 'Control System' at 'Toa Payoh' with severity 'Critical' on 2020-06-17 03:12:05
# ALERT: Fault 'Control System' at 'Bugis Junction' with severity 'Critical' on 2020-06-17 03:59:51
# ALERT: Fault 'Cybersecurity' at 'Pasir Ris' with severity 'Critical' on 2020-06-17 23:52:57
# ALERT: Fault 'Cybersecurity' at 'Toa Payoh' with severity 'Critical' on 2020-06-21 08:29:48
# ALERT: Fault 'Control System' at 'City Hall' with severity 'High' on 2020-06-22 15:33:45
# ALERT: Fault 'Environmental' at 'Chinatown' with severity 'Critical' on 2020-06-23 03:47:18
# ALERT: Fault 'Power-Related' at 'Bugis Junction' with severity 'High' on 2020-06-23 21:02:39
# ALERT: Fault 'Control System' at 'Toa Payoh' with severity 'Critical' on 2020-06-25 05:09:08
# ALERT: Fault 'Power-Related' at 'Bishan' with severity 'Critical' on 2020-07-01 02:48:01
# ALERT: Fault 'Environmental' at 'Jurong West' with severity 'High' on 2020-07-01 22:46:48
# ALERT: Fault 'Cybersecurity' at 'Jurong West' with severity 'High' on 2020-07-02 14:44:17
# ALERT: Fault 'Cybersecurity' at 'Bishan' with severity 'Critical' on 2020-07-04 23:51:35
# ALERT: Fault 'Communication' at 'Toa Payoh' with severity 'High' on 2020-07-05 20:39:21
# ALERT: Fault 'Cybersecurity' at 'Bishan' with severity 'Critical' on 2020-07-06 17:52:13
# ALERT: Fault 'Communication' at 'Canberra' with severity 'Critical' on 2020-07-07 11:52:37
# ALERT: Fault 'Control System' at 'Canberra' with severity 'Critical' on 2020-07-12 23:32:05
# ALERT: Fault 'Control System' at 'Bugis Junction' with severity 'Critical' on 2020-07-13 21:42:14
# ALERT: Fault 'Cybersecurity' at 'Chinatown' with severity 'High' on 2020-07-15 09:49:51
# ALERT: Fault 'Environmental' at 'Canberra' with severity 'Critical' on 2020-07-16 09:38:01
# ALERT: Fault 'Power-Related' at 'Orchard Road' with severity 'High' on 2020-07-16 15:53:23
# ALERT: Fault 'Power-Related' at 'City Hall' with severity 'High' on 2020-07-19 13:21:49
# ALERT: Fault 'Control System' at 'Canberra' with severity 'Critical' on 2020-07-20 23:41:37
# ALERT: Fault 'Sensor-Related' at 'Pasir Ris' with severity 'Critical' on 2020-07-21 00:56:41
# ALERT: Fault 'Cybersecurity' at 'Pasir Ris' with severity 'High' on 2020-07-24 22:57:08
# ALERT: Fault 'Communication' at 'Toa Payoh' with severity 'High' on 2020-07-26 16:10:42
# ALERT: Fault 'Cybersecurity' at 'Toa Payoh' with severity 'High' on 2020-07-27 11:27:38
# ALERT: Fault 'Sensor-Related' at 'City Hall' with severity 'Critical' on 2020-07-27 15:25:25
# ALERT: Fault 'Communication' at 'Bugis Junction' with severity 'Critical' on 2020-07-28 08:19:34
# ALERT: Fault 'Power-Related' at 'Pasir Ris' with severity 'Critical' on 2020-08-01 07:25:15
# ALERT: Fault 'Environmental' at 'Chinatown' with severity 'High' on 2020-08-01 09:10:11
# ALERT: Fault 'Sensor-Related' at 'Canberra' with severity 'High' on 2020-08-02 02:20:18
# ALERT: Fault 'Cybersecurity' at 'Chinatown' with severity 'High' on 2020-08-03 17:39:33
# ALERT: Fault 'Sensor-Related' at 'Bishan' with severity 'High' on 2020-08-09 11:08:09
# ALERT: Fault 'Communication' at 'Bugis Junction' with severity 'Critical' on 2020-08-10 20:21:04
# ALERT: Fault 'Environmental' at 'Chinatown' with severity 'High' on 2020-08-12 12:49:13
# ALERT: Fault 'Sensor-Related' at 'Bishan' with severity 'Critical' on 2020-08-15 10:57:50
# ALERT: Fault 'Communication' at 'Bugis Junction' with severity 'Critical' on 2020-08-16 14:20:28
# ALERT: Fault 'Environmental' at 'Bugis Junction' with severity 'High' on 2020-08-16 19:10:53
# ALERT: Fault 'Power-Related' at 'Bishan' with severity 'High' on 2020-08-20 03:50:58
# ALERT: Fault 'Communication' at 'City Hall' with severity 'Critical' on 2020-08-23 16:15:27
# ALERT: Fault 'Cybersecurity' at 'City Hall' with severity 'High' on 2020-08-29 17:11:23
# ALERT: Fault 'Control System' at 'Bishan' with severity 'Critical' on 2020-08-31 18:34:16
# ALERT: Fault 'Environmental' at 'Pasir Ris' with severity 'High' on 2020-09-01 05:13:56
# ALERT: Fault 'Power-Related' at 'Pasir Ris' with severity 'Critical' on 2020-09-01 16:30:17
# ALERT: Fault 'Power-Related' at 'Bishan' with severity 'Critical' on 2020-09-04 07:45:06
# ALERT: Fault 'Control System' at 'Canberra' with severity 'High' on 2020-09-04 17:26:31
# ALERT: Fault 'Communication' at 'Jurong West' with severity 'Critical' on 2020-09-06 19:20:59
# ALERT: Fault 'Power-Related' at 'Pasir Ris' with severity 'Critical' on 2020-09-12 08:37:49
# ALERT: Fault 'Power-Related' at 'Pasir Ris' with severity 'Critical' on 2020-09-12 14:35:50
# ALERT: Fault 'Environmental' at 'Jurong West' with severity 'Critical' on 2020-09-12 23:28:52
# ALERT: Fault 'Cybersecurity' at 'City Hall' with severity 'Critical' on 2020-09-13 03:07:39
# ALERT: Fault 'Sensor-Related' at 'Toa Payoh' with severity 'Critical' on 2020-09-22 00:28:43
# ALERT: Fault 'Control System' at 'Canberra' with severity 'High' on 2020-09-22 15:19:39
# ALERT: Fault 'Sensor-Related' at 'Canberra' with severity 'Critical' on 2020-09-22 19:59:16
# ALERT: Fault 'Communication' at 'Orchard Road' with severity 'Critical' on 2020-10-01 00:26:40
# ALERT: Fault 'Control System' at 'Canberra' with severity 'Critical' on 2020-10-01 15:31:49
# ALERT: Fault 'Cybersecurity' at 'City Hall' with severity 'High' on 2020-10-02 08:09:42
# ALERT: Fault 'Sensor-Related' at 'Canberra' with severity 'Critical' on 2020-10-04 05:47:17
# ALERT: Fault 'Control System' at 'Jurong West' with severity 'High' on 2020-10-04 13:57:45
# ALERT: Fault 'Control System' at 'Bishan' with severity 'High' on 2020-10-05 12:58:44
# ALERT: Fault 'Communication' at 'Orchard Road' with severity 'Critical' on 2020-10-07 09:19:53
# ALERT: Fault 'Communication' at 'Canberra' with severity 'High' on 2020-10-10 08:49:09
# ALERT: Fault 'Cybersecurity' at 'Outram Park' with severity 'Critical' on 2020-10-15 19:42:16
# ALERT: Fault 'Environmental' at 'Bugis Junction' with severity 'Critical' on 2020-10-16 23:02:58
# ALERT: Fault 'Communication' at 'City Hall' with severity 'Critical' on 2020-10-17 02:59:28
# ALERT: Fault 'Cybersecurity' at 'Toa Payoh' with severity 'Critical' on 2020-10-19 03:11:53
# ALERT: Fault 'Communication' at 'Chinatown' with severity 'High' on 2020-10-19 22:05:23
# ALERT: Fault 'Environmental' at 'City Hall' with severity 'Critical' on 2020-10-20 05:06:20
# ALERT: Fault 'Communication' at 'Orchard Road' with severity 'Critical' on 2020-10-22 06:44:53
# ALERT: Fault 'Communication' at 'Chinatown' with severity 'Critical' on 2020-10-22 19:26:42
# ALERT: Fault 'Environmental' at 'Bugis Junction' with severity 'Critical' on 2020-10-23 13:48:28
# ALERT: Fault 'Control System' at 'Orchard Road' with severity 'High' on 2020-10-23 21:29:15
# ALERT: Fault 'Control System' at 'Toa Payoh' with severity 'High' on 2020-10-24 09:59:20
# ALERT: Fault 'Control System' at 'Orchard Road' with severity 'High' on 2020-10-24 22:08:15
# ALERT: Fault 'Communication' at 'Toa Payoh' with severity 'Critical' on 2020-10-25 08:59:02
# ALERT: Fault 'Sensor-Related' at 'Bugis Junction' with severity 'High' on 2020-10-25 15:32:20
# ALERT: Fault 'Sensor-Related' at 'Orchard Road' with severity 'High' on 2020-10-26 02:48:24
# ALERT: Fault 'Control System' at 'City Hall' with severity 'Critical' on 2020-10-26 19:25:43
# ALERT: Fault 'Environmental' at 'Canberra' with severity 'Critical' on 2020-10-27 01:40:17
# ALERT: Fault 'Power-Related' at 'Outram Park' with severity 'Critical' on 2020-11-01 02:21:17
# ALERT: Fault 'Cybersecurity' at 'Bishan' with severity 'Critical' on 2020-11-02 08:42:59
# ALERT: Fault 'Sensor-Related' at 'Canberra' with severity 'High' on 2020-11-03 20:04:21
# ALERT: Fault 'Communication' at 'Bishan' with severity 'High' on 2020-11-04 01:50:24
# ALERT: Fault 'Environmental' at 'Outram Park' with severity 'High' on 2020-11-08 04:30:13
# ALERT: Fault 'Cybersecurity' at 'City Hall' with severity 'High' on 2020-11-11 10:52:36
# ALERT: Fault 'Cybersecurity' at 'Bugis Junction' with severity 'High' on 2020-11-17 17:31:05
# ALERT: Fault 'Cybersecurity' at 'Bishan' with severity 'Critical' on 2020-11-18 19:03:02
# ALERT: Fault 'Cybersecurity' at 'Pasir Ris' with severity 'Critical' on 2020-11-24 00:30:15
# ALERT: Fault 'Power-Related' at 'Toa Payoh' with severity 'Critical' on 2020-11-24 05:29:17
# ALERT: Fault 'Environmental' at 'Outram Park' with severity 'High' on 2020-11-29 05:32:24
# ALERT: Fault 'Control System' at 'Canberra' with severity 'Critical' on 2020-11-30 01:30:54
# ALERT: Fault 'Communication' at 'Pasir Ris' with severity 'High' on 2020-12-04 20:09:24
# ALERT: Fault 'Power-Related' at 'Orchard Road' with severity 'High' on 2020-12-05 05:02:00
# ALERT: Fault 'Environmental' at 'Jurong West' with severity 'High' on 2020-12-06 18:19:32
# ALERT: Fault 'Environmental' at 'Pasir Ris' with severity 'High' on 2020-12-09 02:31:32
# ALERT: Fault 'Control System' at 'Orchard Road' with severity 'Critical' on 2020-12-16 04:32:01
# ALERT: Fault 'Control System' at 'Bugis Junction' with severity 'Critical' on 2020-12-17 16:23:46
# ALERT: Fault 'Control System' at 'Outram Park' with severity 'Critical' on 2020-12-19 05:43:00
# ALERT: Fault 'Cybersecurity' at 'City Hall' with severity 'High' on 2020-12-22 06:39:51
# ALERT: Fault 'Power-Related' at 'Jurong West' with severity 'Critical' on 2020-12-23 04:52:01
# ALERT: Fault 'Sensor-Related' at 'Bishan' with severity 'Critical' on 2020-12-25 02:34:36
# ALERT: Fault 'Control System' at 'Canberra' with severity 'Critical' on 2020-12-29 20:00:19

# %%
# Create a new DataFrame with only selected columns from all_alerts
styled_alerts = all_alerts[['fault_type', 'location_name', 'severity_level', 'timestamp']].copy()

# Define severity levels colours
severity_colors = {
    "Critical": "background-color: #ff4d4d; color: white; font-weight: bold;", # Red
    "High": "background-color: #ffa500; color: white; font-weight: bold;", # Orange
    "Medium": "background-color: #ffeb3b; color: black;" # Yellow
}

# Return colour for the given severity level
def highlight_severity(val):
    return severity_colors.get(val, "")

# Apply color styling to the severity_level column and set table styles
styled_alerts.style.applymap(highlight_severity, subset=['severity_level']) \
    .set_table_styles([
        {'selector': 'thead th', 'props': [('background-color', '#333'), ('color', 'white'), ('font-weight', 'bold')]},
        {'selector': 'tbody td', 'props': [('border', '1px solid #ccc'), ('padding', '6px')]},
    ]) \
    .set_properties(**{'text-align': 'center'})
# Out:
# /tmp/ipython-input-1786090863.py:16: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_alerts.style.applymap(highlight_severity, subset=['severity_level']) \
# <style type="text/css">
# #T_931cf thead th {
#   background-color: #333;
#   color: white;
#   font-weight: bold;
# }
# #T_931cf tbody td {
#   border: 1px solid #ccc;
#   padding: 6px;
# }
# #T_931cf_row0_col0, #T_931cf_row0_col1, #T_931cf_row0_col3, #T_931cf_row1_col0, #T_931cf_row1_col1, #T_931cf_row1_col3, #T_931cf_row2_col0, #T_931cf_row2_col1, #T_931cf_row2_col3, #T_931cf_row3_col0, #T_931cf_row3_col1, #T_931cf_row3_col3, #T_931cf_row4_col0, #T_931cf_row4_col1, #T_931cf_row4_col3, #T_931cf_row5_col0, #T_931cf_row5_col1, #T_931cf_row5_col3, #T_931cf_row6_col0, #T_931cf_row6_col1, #T_931cf_row6_col3, #T_931cf_row7_col0, #T_931cf_row7_col1, #T_931cf_row7_col3, #T_931cf_row8_col0, #T_931cf_row8_col1, #T_931cf_row8_col3, #T_931cf_row9_col0, #T_931cf_row9_col1, #T_931cf_row9_col3, #T_931cf_row10_col0, #T_931cf_row10_col1, #T_931cf_row10_col3, #T_931cf_row11_col0, #T_931cf_row11_col1, #T_931cf_row11_col3, #T_931cf_row12_col0, #T_931cf_row12_col1, #T_931cf_row12_col3, #T_931cf_row13_col0, #T_931cf_row13_col1, #T_931cf_row13_col3, #T_931cf_row14_col0, #T_931cf_row14_col1, #T_931cf_row14_col3, #T_931cf_row15_col0, #T_931cf_row15_col1, #T_931cf_row15_col3, #T_931cf_row16_col0, #T_931cf_row16_col1, #T_931cf_row16_col3, #T_931cf_row17_col0, #T_931cf_row17_col1, #T_931cf_row17_col3, #T_931cf_row18_col0, #T_931cf_row18_col1, #T_931cf_row18_col3, #T_931cf_row19_col0, #T_931cf_row19_col1, #T_931cf_row19_col3, #T_931cf_row20_col0, #T_931cf_row20_col1, #T_931cf_row20_col3, #T_931cf_row21_col0, #T_931cf_row21_col1, #T_931cf_row21_col3, #T_931cf_row22_col0, #T_931cf_row22_col1, #T_931cf_row22_col3, #T_931cf_row23_col0, #T_931cf_row23_col1, #T_931cf_row23_col3, #T_931cf_row24_col0, #T_931cf_row24_col1, #T_931cf_row24_col3, #T_931cf_row25_col0, #T_931cf_row25_col1, #T_931cf_row25_col3, #T_931cf_row26_col0, #T_931cf_row26_col1, #T_931cf_row26_col3, #T_931cf_row27_col0, #T_931cf_row27_col1, #T_931cf_row27_col3, #T_931cf_row28_col0, #T_931cf_row28_col1, #T_931cf_row28_col3, #T_931cf_row29_col0, #T_931cf_row29_col1, #T_931cf_row29_col3, #T_931cf_row30_col0, #T_931cf_row30_col1, #T_931cf_row30_col3, #T_931cf_row31_col0, #T_931cf_row31_col1, #T_931cf_row31_col3, #T_931cf_row32_col0, #T_931cf_row32_col1, #T_931cf_row32_col3, #T_931cf_row33_col0, #T_931cf_row33_col1, #T_931cf_row33_col3, #T_931cf_row34_col0, #T_931cf_row34_col1, #T_931cf_row34_col3, #T_931cf_row35_col0, #T_931cf_row35_col1, #T_931cf_row35_col3, #T_931cf_row36_col0, #T_931cf_row36_col1, #T_931cf_row36_col3, #T_931cf_row37_col0, #T_931cf_row37_col1, #T_931cf_row37_col3, #T_931cf_row38_col0, #T_931cf_row38_col1, #T_931cf_row38_col3, #T_931cf_row39_col0, #T_931cf_row39_col1, #T_931cf_row39_col3, #T_931cf_row40_col0, #T_931cf_row40_col1, #T_931cf_row40_col3, #T_931cf_row41_col0, #T_931cf_row41_col1, #T_931cf_row41_col3, #T_931cf_row42_col0, #T_931cf_row42_col1, #T_931cf_row42_col3, #T_931cf_row43_col0, #T_931cf_row43_col1, #T_931cf_row43_col3, #T_931cf_row44_col0, #T_931cf_row44_col1, #T_931cf_row44_col3, #T_931cf_row45_col0, #T_931cf_row45_col1, #T_931cf_row45_col3, #T_931cf_row46_col0, #T_931cf_row46_col1, #T_931cf_row46_col3, #T_931cf_row47_col0, #T_931cf_row47_col1, #T_931cf_row47_col3, #T_931cf_row48_col0, #T_931cf_row48_col1, #T_931cf_row48_col3, #T_931cf_row49_col0, #T_931cf_row49_col1, #T_931cf_row49_col3, #T_931cf_row50_col0, #T_931cf_row50_col1, #T_931cf_row50_col3, #T_931cf_row51_col0, #T_931cf_row51_col1, #T_931cf_row51_col3, #T_931cf_row52_col0, #T_931cf_row52_col1, #T_931cf_row52_col3, #T_931cf_row53_col0, #T_931cf_row53_col1, #T_931cf_row53_col3, #T_931cf_row54_col0, #T_931cf_row54_col1, #T_931cf_row54_col3, #T_931cf_row55_col0, #T_931cf_row55_col1, #T_931cf_row55_col3, #T_931cf_row56_col0, #T_931cf_row56_col1, #T_931cf_row56_col3, #T_931cf_row57_col0, #T_931cf_row57_col1, #T_931cf_row57_col3, #T_931cf_row58_col0, #T_931cf_row58_col1, #T_931cf_row58_col3, #T_931cf_row59_col0, #T_931cf_row59_col1, #T_931cf_row59_col3, #T_931cf_row60_col0, #T_931cf_row60_col1, #T_931cf_row60_col3, #T_931cf_row61_col0, #T_931cf_row61_col1, #T_931cf_row61_col3, #T_931cf_row62_col0, #T_931cf_row62_col1, #T_931cf_row62_col3, #T_931cf_row63_col0, #T_931cf_row63_col1, #T_931cf_row63_col3 ...
