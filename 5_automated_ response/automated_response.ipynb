# %% [markdown]
# # Automated Response
# - **Objective:** To generate alerts when certain fault conditions occur

# %%
# Import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split  # Split data for training and testing
from sklearn.preprocessing import LabelEncoder  # Convert text to numbers
from sklearn.tree import DecisionTreeClassifier  # Machine learning model
from sklearn.metrics import classification_report, confusion_matrix  # Check how well the model works

# %%
# Read data file
df = pd.read_csv('lighting_data_cleaned.csv')

# Display data
df
# Out:
#     light_id location_name      fault_type            timestamp  \
# 0      L0313   Jurong West   Power-Related  2020-01-07 09:05:35
# 1      L0385     Pasir Ris   Environmental  2020-01-07 10:28:12
# 2      L0158      Canberra   Communication  2020-01-07 13:09:56
# 3      L0554   Jurong West   Communication  2020-01-08 01:55:51
# 4      L0755        Bishan   Communication  2020-01-11 10:49:07
# ..       ...           ...             ...                  ...
# 163    L0768     Chinatown   Cybersecurity  2020-12-24 21:14:30
# 164    L0716     Pasir Ris  Control System  2020-12-26 03:30:47
# 165    L0085     Toa Payoh   Communication  2020-12-27 02:25:18
# 166    L0525     Pasir Ris  Control System  2020-12-28 00:39:48
# 167    L0904   Outram Park   Environmental  2020-12-29 05:58:29
#
#     severity_level fault_status  maintenance_cost  year  month  day  \
# 0              Low       Closed            297.45  2020      1    7
# 1           Medium  In Progress            172.61  2020      1    7
# 2           Medium     Detected            381.23  2020      1    7
# 3           Medium  In Progress            284.30  2020      1    8
# 4         Critical  In Progress             76.52  2020      1   11
# ..             ...          ...               ...   ...    ...  ...
# 163       Critical     Detected            156.92  2020     12   24
# 164           High       Closed            262.23  2020     12   26
# 165         Medium       Closed            377.93  2020     12   27
# 166            Low  In Progress            191.01  2020     12   28
# 167         Medium     Detected            301.04  2020     12   29
#
#     day_of_week  hour
# 0       Tuesday     9
# 1       Tuesday    10
# 2       Tuesday    13
# 3     Wednesday     1
# 4      Saturday    10
# ..          ...   ...
# 163    Thursday    21
# 164    Saturday     3
# 165      Sunday     2
# 166      Monday     0
# 167     Tuesday     5
#
# [168 rows x 12 columns]

# %%
# Filter faults with severity High or Critical
alert_faults = df[df['severity_level'].isin(['High', 'Critical'])]

# Filter df to include only rows where:
power_alerts = df[
    (df['fault_type'] == 'Power-related') &  # Condition 1: fault_type must be 'Power-related'
    (df['severity_level'].isin(['Medium', 'High', 'Critical']))  # Condition 2: severity_level must be one of these values
]

all_alerts = (
    pd.concat([alert_faults, power_alerts])  # Combine the two filtered dfs 'alert_faults' and 'power_alerts' into one df
    .drop_duplicates()                      # Remove duplicates
    .reset_index(drop=True)                 # Reset index starting at 0
)

# Print the total number of alert records in the 'all_alerts' df
print(f"Total alerts generated: {len(all_alerts)}")

# Alert display
for idx, row in all_alerts.iterrows():
    print(f"ALERT: Fault '{row['fault_type']}' at '{row['location_name']}' with severity '{row['severity_level']}' on {row['timestamp']}")
# Out:
# Total alerts generated: 68
# ALERT: Fault 'Communication' at 'Bishan' with severity 'Critical' on 2020-01-11 10:49:07
# ALERT: Fault 'Cybersecurity' at 'Toa Payoh' with severity 'Critical' on 2020-01-15 17:19:49
# ALERT: Fault 'Control System' at 'Jurong West' with severity 'High' on 2020-01-16 13:53:28
# ALERT: Fault 'Power-Related' at 'Chinatown' with severity 'Critical' on 2020-01-17 03:41:25
# ALERT: Fault 'Control System' at 'Chinatown' with severity 'High' on 2020-01-17 22:03:22
# ALERT: Fault 'Cybersecurity' at 'City Hall' with severity 'High' on 2020-01-25 04:05:58
# ALERT: Fault 'Environmental' at 'Orchard Road' with severity 'Critical' on 2020-01-25 11:30:17
# ALERT: Fault 'Environmental' at 'Orchard Road' with severity 'Critical' on 2020-01-31 02:51:06
# ALERT: Fault 'Communication' at 'Jurong West' with severity 'High' on 2020-02-02 22:13:59
# ALERT: Fault 'Cybersecurity' at 'Bishan' with severity 'Critical' on 2020-02-06 04:23:36
# ALERT: Fault 'Environmental' at 'Outram Park' with severity 'High' on 2020-02-09 22:51:32
# ALERT: Fault 'Cybersecurity' at 'Bishan' with severity 'Critical' on 2020-02-10 21:24:28
# ALERT: Fault 'Communication' at 'Toa Payoh' with severity 'Critical' on 2020-02-11 07:54:50
# ALERT: Fault 'Communication' at 'Outram Park' with severity 'High' on 2020-02-15 21:29:03
# ALERT: Fault 'Cybersecurity' at 'Pasir Ris' with severity 'High' on 2020-02-18 10:15:02
# ALERT: Fault 'Control System' at 'Orchard Road' with severity 'High' on 2020-02-21 10:55:38
# ALERT: Fault 'Sensor-Related' at 'Chinatown' with severity 'Critical' on 2020-02-26 01:33:41
# ALERT: Fault 'Environmental' at 'Bugis Junction' with severity 'Critical' on 2020-03-03 12:38:16
# ALERT: Fault 'Environmental' at 'City Hall' with severity 'High' on 2020-03-09 05:14:18
# ALERT: Fault 'Environmental' at 'Bishan' with severity 'High' on 2020-03-13 07:39:30
# ALERT: Fault 'Control System' at 'Jurong West' with severity 'High' on 2020-03-15 11:40:07
# ALERT: Fault 'Environmental' at 'Outram Park' with severity 'High' on 2020-03-18 18:34:22
# ALERT: Fault 'Control System' at 'Outram Park' with severity 'Critical' on 2020-03-21 12:09:51
# ALERT: Fault 'Cybersecurity' at 'Chinatown' with severity 'High' on 2020-03-23 09:55:21
# ALERT: Fault 'Environmental' at 'Orchard Road' with severity 'High' on 2020-03-28 01:33:43
# ALERT: Fault 'Communication' at 'Pasir Ris' with severity 'Critical' on 2020-04-16 14:11:05
# ALERT: Fault 'Power-Related' at 'Canberra' with severity 'Critical' on 2020-04-24 22:35:36
# ALERT: Fault 'Control System' at 'City Hall' with severity 'High' on 2020-04-29 13:38:00
# ALERT: Fault 'Communication' at 'Bugis Junction' with severity 'Critical' on 2020-04-30 13:36:56
# ALERT: Fault 'Communication' at 'Chinatown' with severity 'High' on 2020-05-07 15:18:50
# ALERT: Fault 'Cybersecurity' at 'Canberra' with severity 'Critical' on 2020-05-07 17:51:07
# ALERT: Fault 'Environmental' at 'Outram Park' with severity 'High' on 2020-05-23 21:10:33
# ALERT: Fault 'Control System' at 'City Hall' with severity 'Critical' on 2020-06-01 08:24:07
# ALERT: Fault 'Control System' at 'Chinatown' with severity 'High' on 2020-06-02 18:45:02
# ALERT: Fault 'Power-Related' at 'Chinatown' with severity 'High' on 2020-06-03 00:11:47
# ALERT: Fault 'Cybersecurity' at 'Pasir Ris' with severity 'Critical' on 2020-06-04 09:53:25
# ALERT: Fault 'Environmental' at 'Toa Payoh' with severity 'Critical' on 2020-06-22 03:46:15
# ALERT: Fault 'Cybersecurity' at 'Toa Payoh' with severity 'Critical' on 2020-06-26 11:12:00
# ALERT: Fault 'Communication' at 'Outram Park' with severity 'Critical' on 2020-07-02 20:46:18
# ALERT: Fault 'Sensor-Related' at 'Outram Park' with severity 'High' on 2020-07-08 12:55:22
# ALERT: Fault 'Communication' at 'Chinatown' with severity 'High' on 2020-07-23 22:23:39
# ALERT: Fault 'Cybersecurity' at 'Bugis Junction' with severity 'Critical' on 2020-07-29 13:57:42
# ALERT: Fault 'Cybersecurity' at 'Toa Payoh' with severity 'High' on 2020-07-30 13:46:47
# ALERT: Fault 'Sensor-Related' at 'Toa Payoh' with severity 'Critical' on 2020-08-02 03:12:37
# ALERT: Fault 'Power-Related' at 'Orchard Road' with severity 'High' on 2020-08-07 18:12:58
# ALERT: Fault 'Environmental' at 'Outram Park' with severity 'High' on 2020-08-11 07:16:35
# ALERT: Fault 'Cybersecurity' at 'Toa Payoh' with severity 'Critical' on 2020-08-16 03:20:01
# ALERT: Fault 'Cybersecurity' at 'Bishan' with severity 'Critical' on 2020-08-21 04:28:37
# ALERT: Fault 'Sensor-Related' at 'Jurong West' with severity 'High' on 2020-08-24 17:11:49
# ALERT: Fault 'Control System' at 'Chinatown' with severity 'Critical' on 2020-09-02 15:29:08
# ALERT: Fault 'Environmental' at 'Chinatown' with severity 'Critical' on 2020-09-07 15:50:02
# ALERT: Fault 'Power-Related' at 'Bishan' with severity 'Critical' on 2020-09-12 18:24:53
# ALERT: Fault 'Power-Related' at 'Toa Payoh' with severity 'High' on 2020-09-16 03:29:31
# ALERT: Fault 'Sensor-Related' at 'City Hall' with severity 'Critical' on 2020-09-21 02:20:28
# ALERT: Fault 'Control System' at 'Bugis Junction' with severity 'High' on 2020-09-27 09:38:08
# ALERT: Fault 'Control System' at 'Orchard Road' with severity 'Critical' on 2020-10-05 14:21:17
# ALERT: Fault 'Cybersecurity' at 'Bugis Junction' with severity 'High' on 2020-10-06 01:25:55
# ALERT: Fault 'Communication' at 'Pasir Ris' with severity 'Critical' on 2020-10-23 15:29:27
# ALERT: Fault 'Power-Related' at 'Bugis Junction' with severity 'Critical' on 2020-10-25 13:50:31
# ALERT: Fault 'Power-Related' at 'Toa Payoh' with severity 'High' on 2020-10-30 06:33:57
# ALERT: Fault 'Communication' at 'Bugis Junction' with severity 'High' on 2020-11-02 08:51:33
# ALERT: Fault 'Power-Related' at 'Orchard Road' with severity 'Critical' on 2020-11-04 23:10:06
# ALERT: Fault 'Sensor-Related' at 'Bishan' with severity 'High' on 2020-11-05 02:44:11
# ALERT: Fault 'Communication' at 'Jurong West' with severity 'Critical' on 2020-12-08 12:13:37
# ALERT: Fault 'Power-Related' at 'Orchard Road' with severity 'High' on 2020-12-11 12:29:11
# ALERT: Fault 'Environmental' at 'City Hall' with severity 'High' on 2020-12-24 18:34:35
# ALERT: Fault 'Cybersecurity' at 'Chinatown' with severity 'Critical' on 2020-12-24 21:14:30
# ALERT: Fault 'Control System' at 'Pasir Ris' with severity 'High' on 2020-12-26 03:30:47

# %%
# Create a new DataFrame with only selected columns from all_alerts
styled_alerts = all_alerts[['fault_type', 'location_name', 'severity_level', 'timestamp']].copy()

# Define severity levels colours
severity_colors = {
    "Critical": "background-color: #ff4d4d; color: white; font-weight: bold;", # Red
    "High": "background-color: #ffa500; color: white; font-weight: bold;", # Orange
    "Medium": "background-color: #ffeb3b; color: black;" # Yellow
}

# Return colour for the given severity level
def highlight_severity(val):
    return severity_colors.get(val, "")

# Apply color styling to the severity_level column and set table styles
styled_alerts.style.applymap(highlight_severity, subset=['severity_level']) \
    .set_table_styles([
        {'selector': 'thead th', 'props': [('background-color', '#333'), ('color', 'white'), ('font-weight', 'bold')]},
        {'selector': 'tbody td', 'props': [('border', '1px solid #ccc'), ('padding', '6px')]},
    ]) \
    .set_properties(**{'text-align': 'center'})
# Out:
# /tmp/ipython-input-1786090863.py:16: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_alerts.style.applymap(highlight_severity, subset=['severity_level']) \
# <style type="text/css">
# #T_7e2c1 thead th {
#   background-color: #333;
#   color: white;
#   font-weight: bold;
# }
# #T_7e2c1 tbody td {
#   border: 1px solid #ccc;
#   padding: 6px;
# }
# #T_7e2c1_row0_col0, #T_7e2c1_row0_col1, #T_7e2c1_row0_col3, #T_7e2c1_row1_col0, #T_7e2c1_row1_col1, #T_7e2c1_row1_col3, #T_7e2c1_row2_col0, #T_7e2c1_row2_col1, #T_7e2c1_row2_col3, #T_7e2c1_row3_col0, #T_7e2c1_row3_col1, #T_7e2c1_row3_col3, #T_7e2c1_row4_col0, #T_7e2c1_row4_col1, #T_7e2c1_row4_col3, #T_7e2c1_row5_col0, #T_7e2c1_row5_col1, #T_7e2c1_row5_col3, #T_7e2c1_row6_col0, #T_7e2c1_row6_col1, #T_7e2c1_row6_col3, #T_7e2c1_row7_col0, #T_7e2c1_row7_col1, #T_7e2c1_row7_col3, #T_7e2c1_row8_col0, #T_7e2c1_row8_col1, #T_7e2c1_row8_col3, #T_7e2c1_row9_col0, #T_7e2c1_row9_col1, #T_7e2c1_row9_col3, #T_7e2c1_row10_col0, #T_7e2c1_row10_col1, #T_7e2c1_row10_col3, #T_7e2c1_row11_col0, #T_7e2c1_row11_col1, #T_7e2c1_row11_col3, #T_7e2c1_row12_col0, #T_7e2c1_row12_col1, #T_7e2c1_row12_col3, #T_7e2c1_row13_col0, #T_7e2c1_row13_col1, #T_7e2c1_row13_col3, #T_7e2c1_row14_col0, #T_7e2c1_row14_col1, #T_7e2c1_row14_col3, #T_7e2c1_row15_col0, #T_7e2c1_row15_col1, #T_7e2c1_row15_col3, #T_7e2c1_row16_col0, #T_7e2c1_row16_col1, #T_7e2c1_row16_col3, #T_7e2c1_row17_col0, #T_7e2c1_row17_col1, #T_7e2c1_row17_col3, #T_7e2c1_row18_col0, #T_7e2c1_row18_col1, #T_7e2c1_row18_col3, #T_7e2c1_row19_col0, #T_7e2c1_row19_col1, #T_7e2c1_row19_col3, #T_7e2c1_row20_col0, #T_7e2c1_row20_col1, #T_7e2c1_row20_col3, #T_7e2c1_row21_col0, #T_7e2c1_row21_col1, #T_7e2c1_row21_col3, #T_7e2c1_row22_col0, #T_7e2c1_row22_col1, #T_7e2c1_row22_col3, #T_7e2c1_row23_col0, #T_7e2c1_row23_col1, #T_7e2c1_row23_col3, #T_7e2c1_row24_col0, #T_7e2c1_row24_col1, #T_7e2c1_row24_col3, #T_7e2c1_row25_col0, #T_7e2c1_row25_col1, #T_7e2c1_row25_col3, #T_7e2c1_row26_col0, #T_7e2c1_row26_col1, #T_7e2c1_row26_col3, #T_7e2c1_row27_col0, #T_7e2c1_row27_col1, #T_7e2c1_row27_col3, #T_7e2c1_row28_col0, #T_7e2c1_row28_col1, #T_7e2c1_row28_col3, #T_7e2c1_row29_col0, #T_7e2c1_row29_col1, #T_7e2c1_row29_col3, #T_7e2c1_row30_col0, #T_7e2c1_row30_col1, #T_7e2c1_row30_col3, #T_7e2c1_row31_col0, #T_7e2c1_row31_col1, #T_7e2c1_row31_col3, #T_7e2c1_row32_col0, #T_7e2c1_row32_col1, #T_7e2c1_row32_col3, #T_7e2c1_row33_col0, #T_7e2c1_row33_col1, #T_7e2c1_row33_col3, #T_7e2c1_row34_col0, #T_7e2c1_row34_col1, #T_7e2c1_row34_col3, #T_7e2c1_row35_col0, #T_7e2c1_row35_col1, #T_7e2c1_row35_col3, #T_7e2c1_row36_col0, #T_7e2c1_row36_col1, #T_7e2c1_row36_col3, #T_7e2c1_row37_col0, #T_7e2c1_row37_col1, #T_7e2c1_row37_col3, #T_7e2c1_row38_col0, #T_7e2c1_row38_col1, #T_7e2c1_row38_col3, #T_7e2c1_row39_col0, #T_7e2c1_row39_col1, #T_7e2c1_row39_col3, #T_7e2c1_row40_col0, #T_7e2c1_row40_col1, #T_7e2c1_row40_col3, #T_7e2c1_row41_col0, #T_7e2c1_row41_col1, #T_7e2c1_row41_col3, #T_7e2c1_row42_col0, #T_7e2c1_row42_col1, #T_7e2c1_row42_col3, #T_7e2c1_row43_col0, #T_7e2c1_row43_col1, #T_7e2c1_row43_col3, #T_7e2c1_row44_col0, #T_7e2c1_row44_col1, #T_7e2c1_row44_col3, #T_7e2c1_row45_col0, #T_7e2c1_row45_col1, #T_7e2c1_row45_col3, #T_7e2c1_row46_col0, #T_7e2c1_row46_col1, #T_7e2c1_row46_col3, #T_7e2c1_row47_col0, #T_7e2c1_row47_col1, #T_7e2c1_row47_col3, #T_7e2c1_row48_col0, #T_7e2c1_row48_col1, #T_7e2c1_row48_col3, #T_7e2c1_row49_col0, #T_7e2c1_row49_col1, #T_7e2c1_row49_col3, #T_7e2c1_row50_col0, #T_7e2c1_row50_col1, #T_7e2c1_row50_col3, #T_7e2c1_row51_col0, #T_7e2c1_row51_col1, #T_7e2c1_row51_col3, #T_7e2c1_row52_col0, #T_7e2c1_row52_col1, #T_7e2c1_row52_col3, #T_7e2c1_row53_col0, #T_7e2c1_row53_col1, #T_7e2c1_row53_col3, #T_7e2c1_row54_col0, #T_7e2c1_row54_col1, #T_7e2c1_row54_col3, #T_7e2c1_row55_col0, #T_7e2c1_row55_col1, #T_7e2c1_row55_col3, #T_7e2c1_row56_col0, #T_7e2c1_row56_col1, #T_7e2c1_row56_col3, #T_7e2c1_row57_col0, #T_7e2c1_row57_col1, #T_7e2c1_row57_col3, #T_7e2c1_row58_col0, #T_7e2c1_row58_col1, #T_7e2c1_row58_col3, #T_7e2c1_row59_col0, #T_7e2c1_row59_col1, #T_7e2c1_row59_col3, #T_7e2c1_row60_col0, #T_7e2c1_row60_col1, #T_7e2c1_row60_col3, #T_7e2c1_row61_col0, #T_7e2c1_row61_col1, #T_7e2c1_row61_col3, #T_7e2c1_row62_col0, #T_7e2c1_row62_col1, #T_7e2c1_row62_col3, #T_7e2c1_row63_col0, #T_7e2c1_row63_col1, #T_7e2c1_row63_col3 ...
#   text-align: center;
# }
# #T_7e2c1_row0_col2, #T_7e2c1_row1_col2, #T_7e2c1_row3_col2, #T_7e2c1_row6_col2, #T_7e2c1_row7_col2, #T_7e2c1_row9_col2, #T_7e2c1_row11_col2, #T_7e2c1_row12_col2, #T_7e2c1_row16_col2, #T_7e2c1_row17_col2, #T_7e2c1_row22_col2, #T_7e2c1_row25_col2, #T_7e2c1_row26_col2, #T_7e2c1_row28_col2, #T_7e2c1_row30_col2, #T_7e2c1_row32_col2, #T_7e2c1_row35_col2, #T_7e2c1_row36_col2, #T_7e2c1_row37_col2, #T_7e2c1_row38_col2, #T_7e2c1_row41_col2, #T_7e2c1_row43_col2, #T_7e2c1_row46_col2, #T_7e2c1_row47_col2, #T_7e2c1_row49_col2, #T_7e2c1_row50_col2, #T_7e2c1_row51_col2, #T_7e2c1_row53_col2, #T_7e2c1_row55_col2, #T_7e2c1_row57_col2, #T_7e2c1_row58_col2, #T_7e2c1_row61_col2, #T_7e2c1_row63_col2, #T_7e2c1_row66_col2 {
#   background-color: #ff4d4d;
#   color: white;
#   font-weight: bold;
#   text-align: center;
# }
# #T_7e2c1_row2_col2, #T_7e2c1_row4_col2, #T_7e2c1_row5_col2, #T_7e2c1_row8_col2, #T_7e2c1_row10_col2, #T_7e2c1_row13_col2, #T_7e2c1_row14_col2, #T_7e2c1_row15_col2, #T_7e2c1_row18_col2, #T_7e2c1_row19_col2, #T_7e2c1_row20_col2, #T_7e2c1_row21_col2, #T_7e2c1_row23_col2, #T_7e2c1_row24_col2, #T_7e2c1_row27_col2, #T_7e2c1_row29_col2, #T_7e2c1_row31_col2, #T_7e2c1_row33_col2, #T_7e2c1_row34_col2, #T_7e2c1_row39_col2, #T_7e2c1_row40_col2, #T_7e2c1_row42_col2, #T_7e2c1_row44_col2, #T_7e2c1_row45_col2, #T_7e2c1_row48_col2, #T_7e2c1_row52_col2, #T_7e2c1_row54_col2, #T_7e2c1_row56_col2, #T_7e2c1_row59_col2, #T_7e2c1_row60_col2, #T_7e2c1_row62_col2, #T_7e2c1_row64_col2, #T_7e2c1_row65_col2, #T_7e2c1_row67_col2 {
#   background-color: #ffa500;
#   color: white;
#   font-weight: bold;
#   text-align: center;
# }
# </style>
# <table id="T_7e2c1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e2c1_level0_col0" class="col_heading level0 col0" >fault_type</th>
#       <th id="T_7e2c1_level0_col1" class="col_heading level0 col1" >location_name</th>
#       <th id="T_7e2c1_level0_col2" class="col_heading level0 col2" >severity_level</th>
#       <th id="T_7e2c1_level0_col3" class="col_heading level0 col3" >timestamp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e2c1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7e2c1_row0_col0" class="data row0 col0" >Communication</td>
#       <td id="T_7e2c1_row0_col1" class="data row0 col1" >Bishan</td>
#       <td id="T_7e2c1_row0_col2" class="data row0 col2" >Critical</td>
#       <td id="T_7e2c1_row0_col3" class="data row0 col3" >2020-01-11 10:49:07</td>
#     </tr>
#     <tr>
#       <th id="T_7e2c1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7e2c1_row1_col0" class="data row1 col0" >Cybersecurity</td>
#       <td id="T_7e2c1_row1_col1" class="data row1 col1" >Toa Payoh</td>
#       <td id="T_7e2c1_row1_col2" class="data row1 col2" >Critical</td>
#       <td id="T_7e2c1_row1_col3" class="data row1 col3" >2020-01-15 17:19:49</td>
#     </tr>
#     <tr>
#       <th id="T_7e2c1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7e2c1_row2_col0" class="data row2 col0" >Control System</td>
#       <td id="T_7e2c1_row2_col1" class="data row2 col1" >Jurong West</td>
#       <td id="T_7e2c1_row2_col2" class="data row2 col2" >High</td>
#       <td id="T_7e2c1_row2_col3" class="data row2 col3" >2020-01-16 13:53:28</td>
#     </tr>
#     <tr>
#       <th id="T_7e2c1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7e2c1_row3_col0" class="data row3 col0" >Power-Related</td>
#       <td id="T_7e2c1_row3_col1" class="data row3 col1" >Chinatown</td>
#       <td id="T_7e2c1_row3_col2" class="data row3 c
