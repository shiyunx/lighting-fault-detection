# %% [markdown]
# # Data Cleaning

# %%
# Import libraries
import pandas as pd
import numpy as np
from google.colab import files

# %%
# Read data file
df = pd.read_csv('lighting_data.csv')

# Display data
df
# Out:
#     light_id   location_name      fault_type            timestamp  \
# 0      L0602       Chinatown   Power-related  2020-01-06 06:34:34
# 1      L0616          Bishan   Power-related  2020-01-06 09:20:51
# 2      L0199  Bugis Junction   Power-related  2020-01-06 19:45:33
# 3      L0036       Chinatown   Power-related  2020-01-07 10:49:23
# 4      L0259       Pasir Ris   Power-related  2020-01-08 16:49:23
# ..       ...             ...             ...                  ...
# 189    L0718       Pasir Ris  Control system  2020-12-27 07:38:39
# 190    L0539  Bugis Junction   Communication  2020-12-28 03:03:47
# 191    L0281     Outram Park   Power-related  2020-12-28 03:22:38
# 192    L0169          Bishan   Environmental  2020-12-28 07:31:05
# 193    L0738       Toa Payoh   Environmental  2020-12-30 01:05:55
#
#     severity_level  fault_status  maintenance_cost
# 0    Informational      Resolved            435.43
# 1    Informational  Acknowledged            456.65
# 2         Critical        Closed            336.82
# 3             High      Resolved            368.61
# 4         Critical        Closed            179.93
# ..             ...           ...               ...
# 189       Critical      Resolved            482.28
# 190  Informational      Detected            183.64
# 191           High        Closed            380.25
# 192       Critical      Detected            308.93
# 193           High      Resolved            350.29
#
# [194 rows x 7 columns]

# %%
# Dataset(rows, columns)
df.shape
# Out:
# (194, 7)

# %%
# Display first five data
df.head()
# Out:
#   light_id   location_name     fault_type            timestamp severity_level  \
# 0    L0602       Chinatown  Power-related  2020-01-06 06:34:34  Informational
# 1    L0616          Bishan  Power-related  2020-01-06 09:20:51  Informational
# 2    L0199  Bugis Junction  Power-related  2020-01-06 19:45:33       Critical
# 3    L0036       Chinatown  Power-related  2020-01-07 10:49:23           High
# 4    L0259       Pasir Ris  Power-related  2020-01-08 16:49:23       Critical
#
#    fault_status  maintenance_cost
# 0      Resolved            435.43
# 1  Acknowledged            456.65
# 2        Closed            336.82
# 3      Resolved            368.61
# 4        Closed            179.93

# %%
# Display last five data
df.tail()
# Out:
#     light_id   location_name      fault_type            timestamp  \
# 189    L0718       Pasir Ris  Control system  2020-12-27 07:38:39
# 190    L0539  Bugis Junction   Communication  2020-12-28 03:03:47
# 191    L0281     Outram Park   Power-related  2020-12-28 03:22:38
# 192    L0169          Bishan   Environmental  2020-12-28 07:31:05
# 193    L0738       Toa Payoh   Environmental  2020-12-30 01:05:55
#
#     severity_level fault_status  maintenance_cost
# 189       Critical     Resolved            482.28
# 190  Informational     Detected            183.64
# 191           High       Closed            380.25
# 192       Critical     Detected            308.93
# 193           High     Resolved            350.29

# %%
# Display summary
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   light_id          194 non-null    object
#  1   location_name     194 non-null    object
#  2   fault_type        194 non-null    object
#  3   timestamp         194 non-null    object
#  4   severity_level    194 non-null    object
#  5   fault_status      194 non-null    object
#  6   maintenance_cost  170 non-null    float64
# dtypes: float64(1), object(6)
# memory usage: 10.7+ KB

# %%
# Find missing values
missing_count = df.isnull().sum()
missing_count
# Out:
# light_id             0
# location_name        0
# fault_type           0
# timestamp            0
# severity_level       0
# fault_status         0
# maintenance_cost    24
# dtype: int64

# %% [markdown]
# The maintenance_cost column has 18 missing values.

# %%
# Find percentage of missing values
missing_count = df.isna().sum()
total_rows = len(df)
missing_proportion = (missing_count / total_rows) * 100

# Sort descending
missing_proportion = missing_proportion.round(2).sort_values(ascending=False)
print(missing_proportion)
# Out:
# maintenance_cost    12.37
# location_name        0.00
# light_id             0.00
# fault_type           0.00
# timestamp            0.00
# severity_level       0.00
# fault_status         0.00
# dtype: float64

# %% [markdown]
# Since the maintenance cost is a numeric column and may contain outliers, the median is used to fill its missing values.

# %%
# Find median of maintenance_cost column
median_value = df['maintenance_cost'].median()
median_rounded = round(median_value, 2)
print("Median value:", median_rounded)
# Out:
# Median value: 272.35

# %%
# Fill missing values with median
df['maintenance_cost'].fillna(median_value, inplace=True)
# Out:
# /tmp/ipykernel_760/2732969241.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['maintenance_cost'].fillna(median_value, inplace=True)

# %%
# Check duplicate rows
num_duplicates = df.duplicated().sum()
print(f"Duplicate rows: {num_duplicates}")
# Out:
# Duplicate rows: 0

# %%
# Verify filling to ensure no null values
print(df['maintenance_cost'].isnull().sum())
# Out:
# 0

# %%
# Convert timestamps to pandas datetime
df['timestamp'] = pd.to_datetime(df['timestamp'])

# Sort by timestamp
df = df.sort_values('timestamp').reset_index(drop=True)

# %%
# Verify data type
print(df['timestamp'].dtype)
# Out:
# datetime64[ns]

# %%
# Verify sort
is_sorted = df['timestamp'].equals(df['timestamp'].sort_values())
print("Is sorted:", is_sorted)
# Out:
# Is sorted: True

# %%
# Standardise categorical values
df['fault_type'] = df['fault_type'].str.strip().str.title()
df['severity_level'] = df['severity_level'].str.strip().str.title()
df['fault_status'] = df['fault_status'].str.strip().str.title()
df['location_name'] = df['location_name'].str.strip().str.title()

# %%
# Extract time features
df['year'] = df['timestamp'].dt.year
df['month'] = df['timestamp'].dt.month
df['day'] = df['timestamp'].dt.day
df['day_of_week'] = df['timestamp'].dt.day_name()
df['hour'] = df['timestamp'].dt.hour

# %%
filename='lighting_data_cleaned.csv'

# Save to csv and download
df.to_csv(filename, index=False) # Save csv
files.download(filename) # Automatically download the file in colab

# Read final dataset
df
# Out:
#     light_id   location_name      fault_type           timestamp  \
# 0      L0602       Chinatown   Power-Related 2020-01-06 06:34:34
# 1      L0616          Bishan   Power-Related 2020-01-06 09:20:51
# 2      L0199  Bugis Junction   Power-Related 2020-01-06 19:45:33
# 3      L0036       Chinatown   Power-Related 2020-01-07 10:49:23
# 4      L0259       Pasir Ris   Power-Related 2020-01-08 16:49:23
# ..       ...             ...             ...                 ...
# 189    L0718       Pasir Ris  Control System 2020-12-27 07:38:39
# 190    L0539  Bugis Junction   Communication 2020-12-28 03:03:47
# 191    L0281     Outram Park   Power-Related 2020-12-28 03:22:38
# 192    L0169          Bishan   Environmental 2020-12-28 07:31:05
# 193    L0738       Toa Payoh   Environmental 2020-12-30 01:05:55
#
#     severity_level  fault_status  maintenance_cost  year  month  day  \
# 0    Informational      Resolved            435.43  2020      1    6
# 1    Informational  Acknowledged            456.65  2020      1    6
# 2         Critical        Closed            336.82  2020      1    6
# 3             High      Resolved            368.61  2020      1    7
# 4         Critical        Closed            179.93  2020      1    8
# ..             ...           ...               ...   ...    ...  ...
# 189       Critical      Resolved            482.28  2020     12   27
# 190  Informational      Detected            183.64  2020     12   28
# 191           High        Closed            380.25  2020     12   28
# 192       Critical      Detected            308.93  2020     12   28
# 193           High      Resolved            350.29  2020     12   30
#
#     day_of_week  hour
# 0        Monday     6
# 1        Monday     9
# 2        Monday    19
# 3       Tuesday    10
# 4     Wednesday    16
# ..          ...   ...
# 189      Sunday     7
# 190      Monday     3
# 191      Monday     3
# 192      Monday     7
# 193   Wednesday     1
#
# [194 rows x 12 columns]
